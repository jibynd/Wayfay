# %%
import  numpy as np
import pandas as pd
import importlib
import simuls, utils 
#from pycaret.regression import *
importlib.reload(simuls)
importlib.reload(utils)
#ExampleThree = simuls.ExampleThree 
from simuls import *
from utils import *

# %%
data = ExampleOne(n = 10, sig = 1, with_test = True).data
data.to_df()
#data.train.to_df(); data.test.to_df()
cols = [col for col in data.df.columns if "x" in col]

# %%
fast_models = ["lr", "br", "lar", "llar", "svm",  "en", "gbr", "omp", "kr"]
slow_models = ["et", "rf", "xgboost", "mlp", "tr", ]

# %%
res_df = pd.DataFrame({"name":my_models}).set_index("name")
res_df[["model", "mse"]] = None
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/qr/nyv7d0vd21x5v4ccll9h77dh0000gn/T/ipykernel_84171/2674185463.py in <module>
# ----> 1 res_df = pd.DataFrame({"name":my_models}).set_index("name")
#       2 res_df[["model", "mse"]] = None
#
# NameError: name 'my_models' is not defined

# %%
tracker = []
for model in fast_models:
    scores = []
    tracker += model
    print("Evaluating "+ model)
    start = time.time(); n_iter = 100
    for i in tqdm(range(n_iter)):
        data = ExampleOne(n = 60, sig=1, with_test = True, seed = i + 1).data
        data.train.to_df(); data.test.to_df()
        out = setup(data = data.train.df, test_data= None, target = "y", silent = True, remove_multicollinearity= True, 
            verbose = False, preprocess = False)
        tuned = tune_model(create_model(model, cross_validation = False, verbose = False), optimize = "MSE", 
            choose_better = True, verbose = False)
        preds = tuned.predict(data.test.df[cols]) 
        scores += [mse(preds, data.test.df["y"])]
    end = time.time() - start 
    name = get_name(tuned)
    res_df.loc[model, ["model", "mse", "time"]] = [name, np.array(scores).mean(), end / n_iter]
    print(res_df.loc[tracker,:])

# %%
def to_latex(df):
    #df.apply(lambda r: print(list(r)), axis = 1)
    df = df.apply(lambda r: " & ".join([str(n) for n in r]), axis = 1)
    return " \\\ \n".join([str(n) for n in df])

# %%
print(to_latex(data.df))
# Out:
# -0.12923458825621756 & -1.434429702400268 & 0.17959348437418554 & -0.6684950824364112 & -0.5126829686769981 & -0.8745657243663252 & -1.2344432228583486 & -0.0541477892718969 & -3.1037639365700818 \\
# 0.3180041356907384 & 0.2777434777925492 & 1.0998106541313377 & -1.3440841380875246 & 0.43054417873261486 & 1.4096454722324077 & -1.1924552898561152 & -0.24132617936989942 & 3.026364433762559 \\
# 1.2060400472318293 & 2.1636607972807647 & 0.46551366808787886 & 0.557165167518914 & -0.09673424986523745 & -0.34230744612603065 & -0.8201322130591547 & 0.0258103283890441 & 5.972524439570202 \\
# -0.5658022494880098 & -0.5775357037985752 & -0.5009192366442087 & -0.07350402119985751 & -0.2057672776117218 & -0.5069009851390212 & -0.7793356583676511 & 0.13053175591475774 & -3.657671593681171 \\
# -0.2221064673460254 & 0.7815868751546843 & -0.9639589155040957 & 0.05726100227553092 & 0.17458982446609855 & 0.28821433971723753 & 0.45143841047026023 & -0.3231715725374747 & 0.29341655843446224 \\
# 1.0415517662121725 & 0.7629152310960879 & 0.3163683914859226 & -0.0010382241133556809 & 0.5587560261741951 & -0.48365906935316105 & -1.6963966656915632 & -1.088019173555242 & 6.576487429698025 \\
# 0.06730988933717413 & -0.05330216524887681 & -0.19000705386264094 & 0.8318551885615197 & 1.5091195162311353 & -0.4598511281330898 & 0.8949823415993681 & 1.2835796089931777 & 2.2475702945456852 \\
# -1.3993335555338045 & -1.4820953141464726 & -0.776081563034509 & -1.891151756317984 & -0.8624704570981993 & 0.07514622639824542 & 0.03075734252053452 & -0.5398578114799878 & -10.405740085519774 \\
# -0.9461445044883943 & -0.797437263005632 & 0.7638694988910237 & 0.18556171637981808 & -0.47707524979807825 & 0.1325308348865269 & -0.9640375728718694 & 0.20660996028919681 & -4.024912843205439 \\
# -0.031164899913040594 & 1.3445119033076718 & -0.2548795912236931 & 0.6638965085247069 & -1.5377699507038058 & -1.630677175328289 & 0.21292846822403982 & 0.15919531656250002 & -2.3298345944079806

# %%
df = pd.read_csv("Data/all.csv")

# %%
df
# Out:
#                        model  name       mse      time  mse_Ex3_1000_5  \
# 0           LinearRegression    lr  0.989403  1.131515       23.720433
# 1              BayesianRidge    br  0.952542  1.180579       23.676756
# 2                       Lars   lar  1.294402  1.392848             NaN
# 3                  LassoLars  llar  3.667148  1.205420       31.235474
# 4                        SVR   svm  5.049048  2.030321       84.819166
# 5                 ElasticNet    en  3.257771  2.062978       63.559658
# 6  GradientBoostingRegressor   gbr  2.857447  5.809546             NaN
# 7  OrthogonalMatchingPursuit   omp  1.011965  1.989719       24.913611
# 8                KernelRidge    kr  0.934544  2.644194       23.700871
#
#    corr_Ex3_1000_5  mse_Ex1_100_5  corr_Ex1_100_5  mse_Ex3_100_1  \
# 0         0.977142      23.620984        0.699355      33.256911
# 1         0.977194      23.632612        0.701417      34.800130
# 2              NaN            NaN             NaN            NaN
# 3         0.974797      26.310254        0.682360       8.055102
# 4         0.952624      20.681242        0.768876     288.320116
# 5         0.968671      25.403486        0.694638      51.847494
# 6              NaN      15.678879        0.840516      90.993400
# 7         0.975964      24.407158        0.685694       1.135010
# 8         0.977164      23.713600        0.700897      34.218550
#
#    corr_Ex3_100_1  mse_Ex1_300_9  corr_Ex1_300_9  mse_Ex2_30  corr_Ex2_30  \
# 0        0.966476      79.577491        0.468998   24.792325     0.896902
# 1        0.964871      79.761412        0.468396   24.930023     0.896902
# 2             NaN            NaN             NaN         NaN          NaN
# 3        0.997404      81.905199        0.458544   27.443125     0.896902
# 4        0.824144      76.222205        0.530146   40.308077     0.853210
# 5        0.976792      81.665330        0.464926   30.295235     0.896902
# 6        0.907555      62.782014        0.691239   24.076626     0.905845
# 7        0.998866      80.627407        0.457122   24.771715     0.896902
# 8        0.965012      80.108761        0.464478   25.201325     0.896902
#
#    mse_Ex3_200_1  corr_Ex3_200_1
# 0       1.290589        0.998694
# 1       1.292773        0.998688
# 2            NaN             NaN
# 3       7.613399        0.997569
# 4     233.854169        0.870674
# 5      50.008831        0.981624
# 6      40.695939        0.959787
# 7       0.973383        0.999008
# 8       1.328084        0.998662

# %%
df.columns
# Out:
# Index(['model', 'name', 'mse', 'time', 'mse_Ex3_1000_5', 'corr_Ex3_1000_5',
#        'mse_Ex1_100_5', 'corr_Ex1_100_5', 'mse_Ex3_100_1', 'corr_Ex3_100_1',
#        'mse_Ex1_300_9', 'corr_Ex1_300_9', 'mse_Ex2_30', 'corr_Ex2_30',
#        'mse_Ex3_200_1', 'corr_Ex3_200_1'],
#       dtype='object')
